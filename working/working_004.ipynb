# %%
# from pathlib import Path
# import pickle

# import aliases


# with (Path(aliases.storagedir) / 'alphacrit_internal_fine.pkl').open(mode='rb') as file:
#     data = pickle.load(file)

# keynames = tuple(sorted((
#     # 'f',
#     # 'aspect',
#     # 'etaDelta',
#     'H',
#     )))
# constants = dict(
#     flux=0.,
#     # H=1.,
#     )

# for key, results in data.items():
#     if not isinstance(key, tuple):
#         key = (key,)
#     params = {**dict(zip(keynames, key)), **constants}
#     alldata[tuple((key, params[key]) for key in sorted(params))] = tuple(results)

# print(len(alldata))



# with (Path(aliases.storagedir) / 'alphacrit_aspect_h_f10.pkl').open(mode='rb') as file:
#     data = pickle.load(file)

# for outerkey, outerdata in data.items():
#     for innerkey, results in outerdata.items():
#         params = dict(aspect=outerkey, H=innerkey, f=1.0)
#         alldata[tuple((key, params[key]) for key in sorted(params))] = tuple(results)

# print(len(alldata))




# alldata2 = {}
# defaults = dict(
#     H=0., flux=None, etaDelta=None, f=1., aspect=1.,
#     )

# for params, results in alldata.items():
#     newparams = dict(params)
#     for key, val in defaults.items():
#         newparams.setdefault(key, val)
#     newparams = tuple((key, newparams[key]) for key in sorted(newparams))
#     alldata2[newparams] = tuple(results)

# with (Path(aliases.storagedir) / 'simple_critical_all.data').open(mode='wb') as file:
#     pickle.dump(alldata2, file)
# Out:
# 4984
