# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# $$
# \frac{dT}{dh} \propto \frac{\phi_q}{s^{*}}
# = -H \frac{\mathrm{Disc}}{{s^*}}
# = -H \frac{h(r^* - f)}{2 r^*}
# = -H \frac{h \left(f h - 2 f - h\right)}{2 \left(f h - f - h\right)}
# $$
