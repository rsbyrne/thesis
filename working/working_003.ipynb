# %%
import aliases

# %%
from thesiscode.referencing.search import search

# %% [markdown]
# $$ {\eta_\Delta^*}^{1-T} $$

# %% [markdown]
# $$
# \nu =
# \begin{cases}
# \eta & \eta < \tau / D \\
# \tau / D &
# \end{cases}
# $$

# %% [markdown]
# ${{T}_{\Delta}}_{\mathrm{ref}}$

# %%
search("climate tectonics")
