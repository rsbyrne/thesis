# %%
from cospar import reader, F, paramkeys, datakeys

# %%
from cospar import merged
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-b08ef90f0f1e> in <module>
# ----> 1 from cospar import merged
#
# ImportError: cannot import name 'merged' from 'cospar' (/home/morpheus/workspace/mount/cospar.py)

# %%
from everest.h5anchor import Reader, Fetch

# %%
merged = Reader('merged', '.')

# %%
merged['oiskeaosle-woatihoo/inputs/freq']
# Out:
# 2.0

# %%
isos = merged[Fetch('*/type') == 'Isovisc']

# %%
inputs
# Out:
# {'xougleirha-scaitkwauzh': {'H': 0.0,
#   'alpha': 1000000.0,
#   'aspect': 0.707,
#   'courant': 1.0,
#   'eta': 1.0,
#   'f': 0.8,
#   'flux': None,
#   'initial': '_built_reafloatwoo-tsaebqeugh',
#   'innerMethod': 'lu',
#   'innerTol': None,
#   'kappa': 1.0,
#   'mgLevels': None,
#   'outerTol': None,
#   'penalty': None,
#   'res': 64,
#   'temperatureDotField': None,
#   'temperatureField': '_built_peaskauslu-thoesfthuec'},
#  'lauspsiaz-jaoqoipi': {'H': 0.0,
#   'alpha': 1000000.0,
#   'aspect': 0.707,
#   'courant': 1.0,
#   'eta': 1.0,
#   'f': 1.0,
#   'flux': None,
#   'initial': '_built_uokuitruetr-shaahbloih',
#   'innerMethod': 'lu',
#   'innerTol': None,
#   'kappa': 1.0,
#   'mgLevels': None,
#   'outerTol': None,
#   'penalty': None,
#   'res': 64,
#   'temperatureDotField': None,
#   'temperatureField': '_built_peaskauslu-thoesfthuec'},
#  'uighaaswuaps-oetsesfaagl': {'H': 0.0,
#   'alpha': 10000.0,
#   'aspect': 1.414,
#   'courant': 1.0,
#   'eta': 1.0,
# ...

# %%
inputs = merged[isos : 'inputs']
# Out:
# /home/morpheus/workspace/mount/everest/everest/h5anchor/reader.py:165: UserWarning: No recognisable tag on string: _built_reafloatwoo-tsaebqeugh
#   warnings.warn(f"No recognisable tag on string: {inp[:32]}")
# /home/morpheus/workspace/mount/everest/everest/h5anchor/reader.py:165: UserWarning: No recognisable tag on string: _built_peaskauslu-thoesfthuec
#   warnings.warn(f"No recognisable tag on string: {inp[:32]}")
# /home/morpheus/workspace/mount/everest/everest/h5anchor/reader.py:165: UserWarning: No recognisable tag on string: _built_uokuitruetr-shaahbloih
#   warnings.warn(f"No recognisable tag on string: {inp[:32]}")
# /home/morpheus/workspace/mount/everest/everest/h5anchor/reader.py:165: UserWarning: No recognisable tag on string: _class_import numpy as np
# from p
#   warnings.warn(f"No recognisable tag on string: {inp[:32]}")
# /home/morpheus/workspace/mount/everest/everest/h5anchor/reader.py:165: UserWarning: No recognisable tag on string: _built_xaflgach-rhoarhngoekw
# ...

# %%
isos
# Out:
# Scope(
# ('xougleirha-scaitkwauzh', '...')
# ('lauspsiaz-jaoqoipi', '...')
# ('uighaaswuaps-oetsesfaagl', '...')
# ('zatnguey-peituatruu', '...')
# ('uoquakoifl-kauswootsao', '...')
# ('baowiegou-kiwlaim', '...')
# ('phaoprzheogr-steisnoavoa', '...')
# ('riesceodrou-soacspoidw', '...')
# ('zhuifceukw-uophistiu', '...')
# ('klaabfaif-iecoipliips', '...')
# ('otaaproufr-skoshghoip', '...')
# ('guefaekreo-fleuplviobr', '...')
# ('faujpsakl-eeraapsoips', '...')
# ('daibsloom-zhuarhexuu', '...')
# ('uapaislaasn-rhaorhdiism', '...')
# ('diixuobua-slaulouvoo', '...')
# ('bliohpreig-tzeepriivii', '...')
# ('spaithrisl-sfiiskuongo', '...')
# ('oeveioastae-eakaoscuoq', '...')
# ('gloekrdwuor-spaogheavuu', '...')
# ('baesix-phauriasfu', '...')
# ('ugraikwoib-athuouoklua', '...')
# ('iulaoaefloi-thaucuipsaa', '...')
# ('fuitwskeing-meatwwrets', '...')
# ('meuglghiugh-tsirhbluadw', '...')
# ('xerhpruuz-smoifrkwuow', '...')
# ('wreofaeluu-iilueaafio', '...')
# ('aereuoablao-oifliugoow', '...')
# ...

# %%
inputs = merged

# %%
isos = merged[
#     (Fetch('*/type') == 'Isovisc') \
    (Fetch('*/inputs/res') == 64) \
    & (Fetch('*/inputs/f') == 1) \
    & (Fetch('*/inputs/aspect') == 1) \
    & (Fetch('*/inputs/alpha') == 1e7) \
    ]
# Out:
# ---------------------------------------------------------------------------
# MismatchingFetchKeys                      Traceback (most recent call last)
# <ipython-input-15-e525bfdfffcc> in <module>
# ----> 1 isos = merged[
#       2 #     (Fetch('*/type') == 'Isovisc') \
#       3     (Fetch('*/inputs/res') == 64) \
#       4     & (Fetch('*/inputs/f') == 1) \
#       5     & (Fetch('*/inputs/aspect') == 1) \
#
# ~/workspace/mount/everest/everest/h5anchor/disk.py in wrapper(self, *args, **kwargs)
#      94     def wrapper(self, *args, **kwargs):
#      95         with H5Wrap(self):
# ---> 96             return func(self, *args, **kwargs)
#      97     return wrapper
#      98
#
# ~/workspace/mount/everest/everest/h5anchor/reader.py in __getitem__(self, inp)
#     254             return [self._getitem(sub) for sub in inp]
#     255         else:
# --> 256             return self._getitem(inp)
#
# ~/workspace/mount/everest/everest/h5anchor/reader.py in _getitem(self, inp)
# ...

# %%
isos
