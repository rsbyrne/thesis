# %% [markdown]
# ```bash
# bash ../../everest/looprun.sh "python3 ../../everest/campaign.py ../../production/simple_critical_f_superfine.py : : : --timeout=7 --workdir=. > camp.log 2>&1 &" 4
# ```

# %%
print('foo')

# %%
(1., 2**0.5, 2.)

# %%
import numpy as np

# %%
vals = tuple(round(float(val), 3) for val in np.linspace(1.2, 1.6, 15))

# %%
vals

# %%
tuple(val / 30 for val in range(25, 30))

# %%
vals[0::3]

# %%
vals[1::3]

# %%
vals[2::3]

# %%
tuple((1, 2, 3))

# %%
import glob
import os

for filename in glob.glob('../data/simple_critical_6/*.job.log'):
    with open(filename, mode='r') as file:
        message = file.read().split('\n')[-2]
    if message == '---ERROR---':
        os.remove(filename)
#         print(filename)

# %%
def myfunc(a, *args, b):
    return a, args, b

myfunc(1, 2, 3, a=4, b=5)

# %%
from planetengine.systems import *

# %%
Isovisc

# %%
system = Isovisc(
    res=64, alpha=1e7, etaDelta=3e4, etaRef=1.,
    )
system.locals.f

# %%
system = Arrhenius(
    res=64, alpha=1e7, etaDelta=3e4, etaRef=1.,
    observers=True,
    )
system[:0.001]()
system.show()
system.report()

# %%
tuple(val / 20 for val in range(20, 9, -1))

# %%
tuple(
    val for val in tuple(val / 100 for val in range(100, 50, -1))
    if val not in tuple(val / 20 for val in range(20, 9, -1))
    )

# %%
dict(
    f=tuple(val / 20 for val in range(20, 5, -1)),
    aspect=tuple(2.**(val / 10) for val in range(0, 11)),
    H=tuple(10.**(val / 10) for val in range(-10, 11)),
    )
