# %% [markdown]
# ```bash
# bash ../../everest/looprun.sh "python3 ../../everest/campaign.py ../../production/simple_critical_6.py : : : --timeout=7 --workdir=. > camp6.log 2>&1 &" 4
# ```

# %%
import glob
import os

for filename in glob.glob('../data/simple_critical_6/*.job.log'):
    with open(filename, mode='r') as file:
        message = file.read().split('\n')[-2]
    if message == '---ERROR---':
        os.remove(filename)
#         print(filename)

# %%
def myfunc(a, *args, b):
    return a, args, b

myfunc(1, 2, 3, a=4, b=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b5469f14f62b> in <module>
#       2     return a, args, b
#       3
# ----> 4 myfunc(1, 2, 3, a=4, b=5)
#
# TypeError: myfunc() got multiple values for argument 'a'

# %%
from planetengine.systems import *

# %%
system = Arrhenius(
    res=64, alpha=1e7, etaDelta=3e4, etaRef=1.,
    observers=True,
    )
system[:0.001]()
system.show()
system.report()

# %%
1e4
# Out:
# 10000.0

# %%
dict(
    f=tuple(val / 20 for val in range(20, 5, -1)),
    aspect=tuple(2.**(val / 10) for val in range(0, 11)),
    H=tuple(10.**(val / 10) for val in range(-10, 11)),
    )
